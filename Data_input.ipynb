# %% [markdown]
# <a href="https://colab.research.google.com/github/Pei-eng/crawler/blob/master/Data_input.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

df1 = pd.read_csv('df_done_2019-10-04_new.csv', encoding = "utf-8")
df1 = df1.drop(columns=['Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22','交通便利性'])
df1 = df1.drop(index=646)

# %%
# def cut_word(x):
#     x.split()

df1['交通便利性']=0
df1
for i in range(len(df1['交通1'])):
#     print(i)
    s = str(df1['交通1'][i]).split(" ")
#     print(s)
    df1['交通便利性'].loc[i]=s[3]

df1
    
#     print(type(i))
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#                   飯店名稱                                                 網址  \
# 0               淺草豪景飯店  https://www.expedia.com.tw/Tokyo-Hotels-Asakus...
# 1           東京御台場希爾頓飯店  https://www.expedia.com.tw/Tokyo-Hotels-Hilton...
# 2                東京庭飯店  https://www.expedia.com.tw/Tokyo-Hotels-Hotel-...
# 3               淺草豪景飯店  https://www.expedia.com.tw/Tokyo-Hotels-Asakus...
# 4           東京新大谷飯店花園樓  https://www.expedia.com.tw/Tokyo-Hotels-Hotel-...
# ..                 ...                                                ...
# 641          東急澀谷卓越大飯店  https://www.expedia.com.tw/Tokyo-Hotels-Shibuy...
# ...

# %%
df1 = df1.reindex(columns=['飯店名稱', '網址', '經度', '緯度', '地址', '鄰近景點1',
                           '鄰近景點2', '鄰近景點3', '鄰近景點4',
                           '鄰近景點5', '交通1', '交通2', '交通3','交通便利性', '廚房', '星等',
                           '評價', '價格', 'CP', 'pre'])

# %% [markdown]
# ## 結論
# 0:
# 4~5星等
# 高價位 (平均一晚 2~3萬元 )
# 低CP ( 平均 0.5 , 可能價格太高 )
# 離羽田機場近 ( 10~30分車程 ) ; 離成田國際機場遠 ( ~50分車程 )
# 較無烹飪設備
#
# 1:
# 1~2星等
# 低價位 (平均一晚 2~3千元 )
# 高CP (平均3.3)
# 離羽田機場近 ( 10~25分車程 ) ; 離成田國際機場遠 ( 40分~1小時車程 )
#
# 2:
# 3星等
# 中等價位 (平均一晚 4~9千元 )
# CP不高不低 ( 平均1.5 )
# 離羽田機場近 ( 10~25分車程 ) ; 離成田國際機場遠 ( 45~55分車程 )

# %%
import sqlalchemy
import pymysql

# %%
#csv檔匯入Mysql資料庫
import pymysql.cursors
import pymysql
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:iii@mysql/test')
with engine.connect() as conn, conn.begin():
    df1.to_sql('hotel', conn, if_exists='replace', index=False)
#     print(df)
connection = pymysql.connect(host='mysql',
                             user='root',
                             password='iii',
                             charset='utf8mb4',
                         cursorclass=pymysql.cursors.DictCursor)
try:
    with connection.cursor() as cursor:
        sql = "USE `test`"
        cursor.execute(sql)
        cursor.execute("SELECT `星等` FROM `hotel`")
        data = cursor.fetchall()
        for i in data: 
            print(i)
        
finally:
    connection.close()
